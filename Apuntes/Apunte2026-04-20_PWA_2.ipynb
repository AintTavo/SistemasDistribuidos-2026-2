# %% [markdown]
# ## Practica No.7 -> App / PWA
#  ||<br>
#  ||<br>
# \  /<br>
#  \\/<br>
# ## No.8 -> Microservicios
#
# La diferencia principal es el service worker.
#
# # Microservicio
# Requiere una API Rest
#
# # App/ PWA
# No es obligatorio tener una api rest, pero estas no son necesarias
#
# # Microservicio
# No requiere principalmente
#
# # Diferencias
# El ambiente y la arquitectura principal de los servicios
